# %% [markdown]
# 1. split preprocessed data in train und validation sets
# 2. create pipeline for Grid Search Algorithm and execute grid search on serveral KNN parameters
# 3. apply KNN with best parameters on splitted train data
# 4. compare ROC to other models
# 5. fit knn model to complete train dataset and apply and test data
# 6. load submission dataset, sort probabilities accordingly and save submission dataset

# %%
import re
from pathlib import Path
import numpy as np
import pandas as pd
import time
from hyperopt import STATUS_OK
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
data_path_raw = Path.cwd().parent / "data" / "raw"

data_path_preprocessed = Path.cwd().parent / "data" / "processed"

# %%
processed_df = pd.read_csv(data_path_preprocessed / "training_set_features__nominal_ordinal_WOE_Impute_Dropped_balanced_stand.csv", index_col="respondent_id")
labels_df = pd.read_csv(data_path_preprocessed / "training_set_labels__balanced.csv", index_col="respondent_id")
test_df_processed = pd.read_csv(data_path_preprocessed / "test_set_features_nominal_ordinal_WOE_Impute_Dropped_Stand.csv", index_col="respondent_id")

# %%
## 1 split preprocessed data in train und validation sets

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    processed_df,
    labels_df,
    shuffle = True,
    test_size = 0.25,
    random_state = 10)

# %%
## 2 create pipeline for Grid Search Algorithm and execute grid search on serveral KNN parameters 
param = {
    'n_neighbors' : [1, 3, 5, 7, 9],
    'weights' : ['uniform', 'distance'],
    'p' : [1, 2]
    }
knn = KNeighborsClassifier()
    

clf = GridSearchCV(knn, param_grid = param, cv = 5, n_jobs=-1)
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']})

# %%
## 2
clf.best_params_
# Out:
# {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}

# %% [markdown]
# {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}

# %%
## 2
results = pd.DataFrame(clf.cv_results_)
results.sort_values(ascending = True, by = 'rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       17.040592      0.822083        85.790601        0.469200
# 1       16.466854      1.033414        85.171488        1.223535
# 5       11.526184      0.848806        89.601168        1.561541
# 9        5.358364      0.172744        80.660944        5.596294
# 2       19.507741      0.566333        86.805318        0.379502
# 3       13.527050      3.500510        86.313864        1.005382
# 13       7.421899      2.172124        72.481576        1.751846
# 17       5.070584      0.952319        73.498276        4.675019
# 4       14.716038      3.281873        92.853602        0.437452
# 7        9.429813      1.292415        71.926762        1.225812
# 8        5.174423      0.415160        76.873632        0.170944
# 11       8.737571      1.282168        77.072742        8.241604
# 12       7.308993      1.549001        73.125189        1.436508
# 6        9.889328      2.547408        81.243660        6.061200
# 16       8.019996      0.980465        71.994940        1.949106
# 15       5.299211      0.263360        74.577526        0.935906
# 19       5.581828      0.881548        50.487269       13.106909
# 10       5.815889      0.410345        93.003678        0.859178
# 14       6.495887      2.378672        71.135515        1.666964
# 18       5.381442      0.669602        80.837322        1.272370
#
#    param_n_neighbors param_p param_weights  \
# 0                  1       1       uniform
# 1                  1       1      distance
# 5                  3       1      distance
# 9                  5       1      distance
# 2                  1       2       uniform
# 3                  1       2      distance
# 13                 7       1      distance
# 17                 9       1      distance
# 4                  3       1       uniform
# 7                  3       2      distance
# 8                  5       1       uniform
# 11                 5       2      distance
# 12                 7       1       uniform
# 6                  3       2       uniform
# 16                 9       1       uniform
# 15                 7       2      distance
# 19                 9       2      distance
# 10                 5       2       uniform
# 14                 7       2       uniform
# 18                 9       2       uniform
#
#                                                params  split0_test_score  \
# 0    {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}           0.816472
# 1   {'n_neighbors': 1, 'p': 1, 'weights': 'distance'}           0.816472
# 5   {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}           0.807572
# 9   {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}           0.796540
# 2    {'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}           0.800301
# 3   {'n_neighbors': 1, 'p': 2, 'weights': 'distance'}           0.800301
# 13  {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}           0.793531
# 17  {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}           0.788392
# 4    {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}           0.778237
# 7   {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}           0.769337
# 8    {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}           0.752413
# 11  {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}           0.746897
# 12   {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}           0.742510
# 6    {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}           0.739000
# 16   {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}           0.731979
# 15  {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}           0.734487
# 19  {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}           0.728845
# 10   {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}           0.705403
# 14   {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}           0.686098
# 18   {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}           0.675693
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.818729           0.816222           0.814341
# 1            0.818729           0.816222           0.814341
# 5            0.803811           0.801554           0.804187
# 9            0.798044           0.796665           0.798546
# 2            0.797418           0.794158           0.796415
# 3            0.797418           0.794158           0.796415
# 13           0.792905           0.791275           0.792278
# 17           0.787765           0.785383           0.783503
# 4            0.779616           0.775605           0.779867
# 7            0.767206           0.760060           0.762442
# 8            0.761564           0.756299           0.762191
# 11           0.749906           0.744766           0.749154
# 12           0.746897           0.739376           0.750407
# 6            0.741381           0.730350           0.734236
# 16           0.734487           0.731353           0.735490
# 15           0.735866           0.733233           0.731979
# 19           0.726840           0.722201           0.723956
# 10           0.712298           0.702269           0.711922
# 14           0.690234           0.681710           0.687727
# 18           0.677573           0.666792           0.673687
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.815971         0.816347        0.001405                1
# 1            0.815971         0.816347        0.001405                1
# 5            0.807948         0.805014        0.002419                3
# 9            0.799173         0.797794        0.001037                4
# 2            0.799298         0.797518        0.002165                5
# 3            0.799298         0.797518        0.002165                5
# 13           0.795412         0.793080        0.001384                7
# 17           0.790648         0.787138        0.002473                8
# 4            0.781497         0.778965        0.001973                9
# 7            0.770214         0.765852        0.003954               10
# 8            0.760311         0.758556        0.003692               11
# 11           0.753918         0.748928        0.003077               12
# 12           0.750157         0.745869        0.004324               13
# 6            0.742134         0.737420        0.004484               14
# 16           0.740629         0.734788        0.003298               15
# 15           0.736242         0.734361        0.001598               16
# 19           0.730350         0.726439        0.003012               17
# 10           0.711170         0.708612        0.004040               18
# 14           0.690987         0.687351        0.003319               19
# 18           0.682713         0.675291        0.005201               20

# %%
## 3 apply KNN with best parameters on splitted train data 


knn = KNeighborsClassifier(n_neighbors=1, weights='uniform', p = 1)

start = time.time()
knn.fit(X_train, y_train)
test_probability = knn.predict_proba(X_test)
end = time.time()
print(end - start)
# Out:
# 109.24370288848877

# %%
## 3 
y_preds = pd.DataFrame(
    {
        "h1n1_vaccine": test_probability[0][:, 1],
        "seasonal_vaccine": test_probability[1][:, 1],
    },
    index = y_test.index
)
print("y_preds.shape:", y_preds.shape)
y_preds.head()
# Out:
# y_preds.shape: (13295, 2)
#                h1n1_vaccine  seasonal_vaccine
# respondent_id
# 44713                   1.0               1.0
# 7604                    0.0               0.0
# 8302                    0.0               1.0
# 33252                   1.0               0.0
# 25581                   0.0               1.0

# %%
## 3 
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_test, y_preds))
# Out:
# 0.9019025457625856

# %%
## 4 compare to other executions 

ROC_3nn =  [0.6996214808883037 , 29.148728132247925]
ROC_5nn = [0.7229525862994551 , 29.378359079360962]
ROC_7nn = [0.7397354504203681, 29.483131170272827]
ROC_5nn_weighed = [0.7265594059943381, 33.25474190711975]
ROC_7nn_weighed = [0.7431371259324109, 34.52661919593811]
ROC_Grid_search_1 = [0.7695095328560894, 28.562514066696167]
ROC_Grid_search_2 = [0.9019025457625856, 109.24370288848877]




ROC_Overview = pd.DataFrame( [ROC_3nn, ROC_5nn, ROC_7nn, ROC_5nn_weighed,ROC_7nn_weighed, ROC_Grid_search])
ROC_Overview.columns = ['ROC', 'Time']
ROC_Overview.index = ['ROC_3nn', 'ROC_5nn', 'ROC_7nn', 'ROC_5nn_weighed', 'ROC_7nn_weighed', 'ROC_Grid_search']
ROC_Overview
# Out:
#                       ROC       Time
# ROC_3nn          0.699621  29.148728
# ROC_5nn          0.722953  29.378359
# ROC_7nn          0.739735  29.483131
# ROC_5nn_weighed  0.726559  33.254742
# ROC_7nn_weighed  0.743137  34.526619
# ROC_Grid_search  0.769510  28.562514

# %%
## 5 fit knn model to complete train dataset and apply and test data

knn.fit(processed_df, labels_df)
test_probability = knn.predict_proba(test_df_processed)

# %%
## 6 load submission dataset, sort probabilities accordingly and save submission dataset 

predictions = pd.DataFrame(
    {
        "h1n1_vaccine": test_probability[0][:, 1],
        "seasonal_vaccine": test_probability[1][:, 1],
    },
    index = test_df_processed.index
)

# %%
## 6
submission_df = pd.read_csv(data_path_raw / "submission_format.csv", 
                            index_col="respondent_id")

# %%
## 6
np.testing.assert_array_equal(test_df_processed.index.values, 
                              submission_df.index.values)

# %%
## 6
# Save predictions to submission data frame
submission_df["h1n1_vaccine"] = predictions["h1n1_vaccine"]
submission_df["seasonal_vaccine"] = predictions["seasonal_vaccine"]

# %%
## 6

output_path = Path.cwd().parent / "models" / "submissions"


submission_df.to_csv(output_path /'KNN_GridSearch.csv', index=True)
