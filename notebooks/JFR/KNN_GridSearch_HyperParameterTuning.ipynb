# %% [markdown]
# 1. Train Validate Data Split
# 2. GridSearch for best parameter combination
# 3. KNN with best parameter combination

# %%
import re
from pathlib import Path
import numpy as np
import pandas as pd
import time
from hyperopt import STATUS_OK
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
data_path_raw = Path.cwd().parent.parent / "data" / "raw"

data_path_preprocessed = Path.cwd().parent.parent / "data" / "processed"

# %%
raw_df_processed = pd.read_csv(data_path_preprocessed / "training_set_features_encoded_imputed_standardized.csv", index_col="respondent_id")
labels_df = pd.read_csv(data_path_raw / "training_set_labels.csv", index_col="respondent_id")
test_df_processed = pd.read_csv(data_path_preprocessed / "test_set_features_encoded_imputed_standardized.csv", index_col="respondent_id")

all_raw_df = raw_df_processed.join(labels_df)

# %%
# Create the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    raw_df_processed,
    labels_df,
    shuffle = True,
    test_size = 0.25,
    random_state = 10)

# %%
param = {
    'n_neighbors' : [1, 3, 5, 7, 9],
    'weights' : ['uniform', 'distance'],
    'p' : [1, 2]
    }
knn = KNeighborsClassifier()
    

clf = GridSearchCV(knn, param_grid = param, cv = 5, n_jobs=-1)
clf.fit(X_train, y_train)
# Out:
# {'mean_fit_time': array([1.65570102, 1.42086263, 1.17224278, 1.33470097, 1.43954864,
#         1.0859304 , 1.10011306, 1.12572765, 1.04070244, 0.9834373 ,
#         1.09257312, 1.17196398, 1.18226466, 1.34015241, 1.33047037,
#         1.088798  , 1.07904549, 1.10687342, 1.27871461, 1.01740589]),
#  'std_fit_time': array([0.19002084, 0.27861277, 0.04383297, 0.17160421, 0.20065829,
#         0.02569707, 0.04426454, 0.020972  , 0.03088449, 0.03417254,
#         0.04716863, 0.12994948, 0.11905636, 0.07984982, 0.08866542,
#         0.05232486, 0.0126294 , 0.13990796, 0.08587741, 0.13389429]),
#  'mean_score_time': array([16.00109596, 15.59435363, 15.75060439, 15.13066607, 15.96120696,
#         15.95974379, 15.79670281, 14.93841319, 15.66205096, 15.29133248,
#         15.77907486, 16.75441041, 17.6121172 , 17.21349773, 17.0717452 ,
#         16.3696032 , 16.05460639, 16.19822636, 17.29297371, 10.8504086 ]),
#  'std_score_time': array([0.12931597, 0.13471147, 0.10611433, 0.22689463, 0.32938509,
#         0.10491116, 0.59882656, 0.03734573, 0.04860223, 0.1437427 ,
#         0.13555131, 0.63797197, 0.15123309, 0.08234959, 0.42057725,
#         0.06531023, 0.07046784, 0.38857345, 0.1336703 , 2.9217604 ]),
#  'param_n_neighbors': masked_array(data=[1, 1, 1, 1, 3, 3, 3, 3, 5, 5, 5, 5, 7, 7, 7, 7, 9, 9,
#                     9, 9],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_p': masked_array(data=[1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1,
#                     2, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_weights': masked_array(data=['uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_neighbors': 1, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 1, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 1, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 1, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 3, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 3, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 5, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 5, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 7, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 7, 'p': 2, 'weights': 'distance'},
#   {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'},
#   {'n_neighbors': 9, 'p': 1, 'weights': 'distance'},
#   {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'},
#   {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}],
#  'split0_test_score': array([0.52071892, 0.52071892, 0.51497753, 0.51497753, 0.57338992,
#         0.57413879, 0.56714928, 0.5673989 , 0.59236146, 0.59161258,
#         0.5761358 , 0.57663505, 0.59610584, 0.59785322, 0.5878682 ,
#         0.58811782, 0.60708937, 0.60758862, 0.59410884, 0.59460809]),
#  'split1_test_score': array([0.51098352, 0.51098352, 0.50049925, 0.50049925, 0.56340489,
#         0.56290564, 0.5536695 , 0.55391912, 0.5908637 , 0.59061408,
#         0.57788318, 0.57763355, 0.6005991 , 0.59985022, 0.58037943,
#         0.57988018, 0.61582626, 0.61582626, 0.59335996, 0.59186221]),
#  'split2_test_score': array([0.51597604, 0.51597604, 0.49925112, 0.49925112, 0.56689965,
#         0.56665002, 0.5556665 , 0.55591613, 0.59460809, 0.59410884,
#         0.57513729, 0.57513729, 0.60209685, 0.60084873, 0.5888667 ,
#         0.5888667 , 0.61407888, 0.61208188, 0.59261108, 0.59236146]),
#  'split3_test_score': array([0.51847229, 0.51847229, 0.50124813, 0.50124813, 0.56315527,
#         0.56265602, 0.55267099, 0.55292062, 0.57838243, 0.57838243,
#         0.5673989 , 0.56789815, 0.59161258, 0.59036445, 0.58112831,
#         0.58062906, 0.59435846, 0.59535696, 0.58587119, 0.58562157]),
#  'split4_test_score': array([0.52371443, 0.52371443, 0.51347978, 0.51347978, 0.57314029,
#         0.57289066, 0.554668  , 0.55416875, 0.58761857, 0.58587119,
#         0.57513729, 0.57463804, 0.6015976 , 0.59985022, 0.58187718,
#         0.58162756, 0.6103345 , 0.61108337, 0.58961558, 0.58861707]),
#  'mean_test_score': array([0.51797304, 0.51797304, 0.50589116, 0.50589116, 0.567998  ,
#         0.56784823, 0.55676485, 0.5568647 , 0.58876685, 0.58811782,
#         0.57433849, 0.57438842, 0.5984024 , 0.59775337, 0.58402396,
#         0.58382426, 0.60833749, 0.60838742, 0.59111333, 0.59061408]),
#  'std_test_score': array([0.00432652, 0.00432652, 0.00685376, 0.00685376, 0.00450047,
#         0.0048543 , 0.00528735, 0.0053548 , 0.00566732, 0.0055527 ,
#         0.0036119 , 0.0034154 , 0.00400149, 0.00382049, 0.00359183,
#         0.00385879, 0.00761583, 0.00702402, 0.00303272, 0.00314568]),
#  'rank_test_score': array([17, 17, 19, 19, 13, 14, 16, 15,  7,  8, 12, 11,  3,  4,  9, 10,  2,
#          1,  5,  6], dtype=int32)}

# %%
clf.best_params_
# Out:
# {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}

# %%
results = pd.DataFrame(clf.cv_results_)
results.sort_values(ascending = True, by = 'rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17       1.106873      0.139908        16.198226        0.388573
# 16       1.079045      0.012629        16.054606        0.070468
# 12       1.182265      0.119056        17.612117        0.151233
# 13       1.340152      0.079850        17.213498        0.082350
# 18       1.278715      0.085877        17.292974        0.133670
# 19       1.017406      0.133894        10.850409        2.921760
# 8        1.040702      0.030884        15.662051        0.048602
# 9        0.983437      0.034173        15.291332        0.143743
# 14       1.330470      0.088665        17.071745        0.420577
# 15       1.088798      0.052325        16.369603        0.065310
# 11       1.171964      0.129949        16.754410        0.637972
# 10       1.092573      0.047169        15.779075        0.135551
# 4        1.439549      0.200658        15.961207        0.329385
# 5        1.085930      0.025697        15.959744        0.104911
# 7        1.125728      0.020972        14.938413        0.037346
# 6        1.100113      0.044265        15.796703        0.598827
# 1        1.420863      0.278613        15.594354        0.134711
# 0        1.655701      0.190021        16.001096        0.129316
# 3        1.334701      0.171604        15.130666        0.226895
# 2        1.172243      0.043833        15.750604        0.106114
#
#    param_n_neighbors param_p param_weights  \
# 17                 9       1      distance
# 16                 9       1       uniform
# 12                 7       1       uniform
# 13                 7       1      distance
# 18                 9       2       uniform
# 19                 9       2      distance
# 8                  5       1       uniform
# 9                  5       1      distance
# 14                 7       2       uniform
# 15                 7       2      distance
# 11                 5       2      distance
# 10                 5       2       uniform
# 4                  3       1       uniform
# 5                  3       1      distance
# 7                  3       2      distance
# 6                  3       2       uniform
# 1                  1       1      distance
# 0                  1       1       uniform
# 3                  1       2      distance
# 2                  1       2       uniform
#
#                                                params  split0_test_score  \
# 17  {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}           0.607589
# 16   {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}           0.607089
# 12   {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}           0.596106
# 13  {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}           0.597853
# 18   {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}           0.594109
# 19  {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}           0.594608
# 8    {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}           0.592361
# 9   {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}           0.591613
# 14   {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}           0.587868
# 15  {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}           0.588118
# 11  {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}           0.576635
# 10   {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}           0.576136
# 4    {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}           0.573390
# 5   {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}           0.574139
# 7   {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}           0.567399
# 6    {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}           0.567149
# 1   {'n_neighbors': 1, 'p': 1, 'weights': 'distance'}           0.520719
# 0    {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}           0.520719
# 3   {'n_neighbors': 1, 'p': 2, 'weights': 'distance'}           0.514978
# 2    {'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}           0.514978
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 17           0.615826           0.612082           0.595357
# 16           0.615826           0.614079           0.594358
# 12           0.600599           0.602097           0.591613
# 13           0.599850           0.600849           0.590364
# 18           0.593360           0.592611           0.585871
# 19           0.591862           0.592361           0.585622
# 8            0.590864           0.594608           0.578382
# 9            0.590614           0.594109           0.578382
# 14           0.580379           0.588867           0.581128
# 15           0.579880           0.588867           0.580629
# 11           0.577634           0.575137           0.567898
# 10           0.577883           0.575137           0.567399
# 4            0.563405           0.566900           0.563155
# 5            0.562906           0.566650           0.562656
# 7            0.553919           0.555916           0.552921
# 6            0.553669           0.555667           0.552671
# 1            0.510984           0.515976           0.518472
# 0            0.510984           0.515976           0.518472
# 3            0.500499           0.499251           0.501248
# 2            0.500499           0.499251           0.501248
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 17           0.611083         0.608387        0.007024                1
# 16           0.610334         0.608337        0.007616                2
# 12           0.601598         0.598402        0.004001                3
# 13           0.599850         0.597753        0.003820                4
# 18           0.589616         0.591113        0.003033                5
# 19           0.588617         0.590614        0.003146                6
# 8            0.587619         0.588767        0.005667                7
# 9            0.585871         0.588118        0.005553                8
# 14           0.581877         0.584024        0.003592                9
# 15           0.581628         0.583824        0.003859               10
# 11           0.574638         0.574388        0.003415               11
# 10           0.575137         0.574338        0.003612               12
# 4            0.573140         0.567998        0.004500               13
# 5            0.572891         0.567848        0.004854               14
# 7            0.554169         0.556865        0.005355               15
# 6            0.554668         0.556765        0.005287               16
# 1            0.523714         0.517973        0.004327               17
# 0            0.523714         0.517973        0.004327               17
# 3            0.513480         0.505891        0.006854               19
# 2            0.513480         0.505891        0.006854               19

# %%
knn = KNeighborsClassifier(n_neighbors=9, weights='distance', p = 1)

start = time.time()
knn.fit(X_train, y_train)
test_predictions = knn.predict(X_test)
test_probability = knn.predict_proba(X_test)
end = time.time()
print(end - start)
# Out:
# 28.562514066696167

# %%
y_preds = pd.DataFrame(
    {
        "h1n1_vaccine": test_probability[0][:, 1],
        "seasonal_vaccine": test_probability[1][:, 1],
    },
    index = y_test.index
)
print("y_preds.shape:", y_preds.shape)
y_preds.head()
# Out:
# y_preds.shape: (6677, 2)
#                h1n1_vaccine  seasonal_vaccine
# respondent_id
# 2653               0.225337          0.894359
# 9506               0.231998          0.343616
# 23107              0.092172          0.142329
# 22648              0.000000          0.561493
# 25589              0.212942          0.549736

# %%
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_test, y_preds))
# Out:
# 0.7695095328560894

# %%
ROC_3nn =  [0.6996214808883037 , 29.148728132247925]
ROC_5nn = [0.7229525862994551 , 29.378359079360962]
ROC_7nn = [0.7397354504203681, 29.483131170272827]
ROC_5nn_weighed = [0.7265594059943381, 33.25474190711975]
ROC_7nn_weighed = [0.7431371259324109, 34.52661919593811]
ROC_Grid_search = [0.7695095328560894, 28.562514066696167]




ROC_Overview = pd.DataFrame( [ROC_3nn, ROC_5nn, ROC_7nn, ROC_5nn_weighed,ROC_7nn_weighed, ROC_Grid_search])
ROC_Overview.columns = ['ROC', 'Time']
ROC_Overview.index = ['ROC_3nn', 'ROC_5nn', 'ROC_7nn', 'ROC_5nn_weighed', 'ROC_7nn_weighed', 'ROC_Grid_search']
ROC_Overview
# Out:
#                       ROC       Time
# ROC_3nn          0.699621  29.148728
# ROC_5nn          0.722953  29.378359
# ROC_7nn          0.739735  29.483131
# ROC_5nn_weighed  0.726559  33.254742
# ROC_7nn_weighed  0.743137  34.526619
# ROC_Grid_search  0.769510  28.562514

# %%
from sklearn.metrics import classification_report
#print(classification_report(y_train, train_predictions))
print(classification_report(y_test, test_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.33      0.43      1410
#            1       0.70      0.69      0.69      3137
#
#    micro avg       0.68      0.58      0.63      4547
#    macro avg       0.66      0.51      0.56      4547
# weighted avg       0.68      0.58      0.61      4547
#  samples avg       0.32      0.30      0.30      4547
# /Users/johannes/opt/anaconda3/envs/py37-ds/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/johannes/opt/anaconda3/envs/py37-ds/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
